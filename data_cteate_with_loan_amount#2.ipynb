# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#    PROD_ID         CIFNO    ACCOUNT_NO ACCOUNT_STATUS PRODUCT_DESC  \
# 0        2  998101782755  103020266468              D      Savings
# 1        2  998101242090  098300061951            NaN      Savings
# 2        2  998101585644  039810184310              A      Savings
# 3        2  998000137604  043020127622              A      Savings
# 4        2  998R00652174  080020298762              A      Savings
#
#            SUB_PRODUCT_DESC   BAL_OS  AVG_BAL LAST_TRAN_DATE  TOTAL_CR  \
# 0         SAVINGS - GENERAL     0.00     0.00      2/20/2018      0.00
# 1  SAVINGS MAJOR INVESTMENT  5132.92  5120.87            NaN       NaN
# 2             SAVINGS - FCY    22.93    22.93      5/25/2022      0.00
# 3           SAVINGS - MINOR  1042.50  1039.98      1/11/2009      3.03
# 4           SAVINGS - MINOR  1005.43  1001.59     10/25/2023      4.61
#
#    TOTAL_DR  NO_CR  NO_DR  NET_FEE_INCOME  NET_INTEREST_INCOME CURRENCY_CD  \
# ...

# %%
encodings_to_try = ['utf-8-sig', 'latin-1', 'ISO-8859-1']

for encoding in encodings_to_try:
    try:
        df = pd.read_csv("C:/Users/15694/Desktop/Cross selling/code/Michelle/dataCopy.csv", encoding=encoding)
        break
    except UnicodeDecodeError:
        continue
# Out:
# C:\Users\15694\AppData\Local\Temp\ipykernel_24724\3072196217.py:5: DtypeWarning: Columns (2,30,31,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/15694/Desktop/Cross selling/code/Michelle/dataCopy.csv", encoding=encoding)

# %%
df.shape
# Out:
# (1616891, 126)

# %%
encodings_to_try = ['utf-8-sig', 'latin-1', 'ISO-8859-1']

for encoding in encodings_to_try:
    try:
        df_l = pd.read_csv("C:/Users/15694/Desktop/Cross selling/code/Michelle/Loan Amounts.csv", encoding=encoding)
        break
    except UnicodeDecodeError:
        continue
# Out:
# C:\Users\15694\AppData\Local\Temp\ipykernel_24724\734080862.py:5: DtypeWarning: Columns (67,95,100,115,119,125,131,133,146,161,164,358,387,443,444,445) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_l = pd.read_csv("C:/Users/15694/Desktop/Cross selling/code/Michelle/Loan Amounts.csv", encoding=encoding)

# %%
df_l.head()
# Out:
#    PROD_ID         CIFNO    ACCOUNT_NO ACCOUNT_STATUS PRODUCT_DESC  \
# 0        1  998001121520  109040081193              A         Loan
# 1        1  998R00048273  181040015631              A         Loan
# 2        1  998101665146  122040062666              A         Loan
# 3        1  998101825776  226040011820              A         Loan
# 4        1  998100405851  187040037651              A         Loan
#
#     SUB_PRODUCT_DESC      BAL_OS     AVG_BAL LAST_TRAN_DATE  TOTAL_CR  \
# 0        STAFF LOANS   145000.00   146935.48      1/24/2023       NaN
# 1  DEVELOPMENT LOANS   140000.00   140000.00            NaN       NaN
# 2     PERSONAL LOANS   380673.45   382469.56      1/10/2023       NaN
# 3     PERSONAL LOANS  6550289.05  6550289.05       1/1/2023       NaN
# 4        STAFF LOANS    18106.62    18135.94      1/24/2023       NaN
#
#    TOTAL_DR  NO_CR  NO_DR  NET_FEE_INCOME  NET_INTEREST_INCOME CURRENCY_CD  \
# ...

# %%
df_l.shape
# Out:
# (52167, 449)

# %%
df_l1=df_l[["CIFNO","LNAMOUNT"]]

# %%
df_l1.shape
# Out:
# (52167, 2)

# %%
sum_by_cif = df_l1.groupby('CIFNO')['LNAMOUNT'].sum().reset_index()

# %%
sum_by_cif.shape
# Out:
# (38600, 2)

# %%
unique_cifno_count_lnamount = sum_by_cif['CIFNO'].nunique()

if unique_cifno_count_lnamount== len(sum_by_cif):
    print("All CIFNO values are unique.")
else:
    print("There are duplicate CIFNO values.")
# Out:
# All CIFNO values are unique.

# %%
sum_by_cif.head()
# Out:
#           CIFNO   LNAMOUNT
# 0  998000000102  4480000.0
# 1  998000000173  2500000.0
# 2  998000000219  3600000.0
# 3  998000000262   475000.0
# 4  998000000312    69000.0

# %%
# Merge based on CIFNO and ACCOUNT_NO
merged_df = pd.merge(df, sum_by_cif, on=['CIFNO'], how='left')

# %%
merged_df.head()
# Out:
#    PROD_ID         CIFNO    ACCOUNT_NO ACCOUNT_STATUS PRODUCT_DESC  \
# 0        2  998101782755  103020266468              D      Savings
# 1        2  998101242090  098300061951            NaN      Savings
# 2        2  998101585644  039810184310              A      Savings
# 3        2  998000137604  043020127622              A      Savings
# 4        2  998R00652174  080020298762              A      Savings
#
#            SUB_PRODUCT_DESC   BAL_OS  AVG_BAL LAST_TRAN_DATE  TOTAL_CR  \
# 0         SAVINGS - GENERAL     0.00     0.00      2/20/2018      0.00
# 1  SAVINGS MAJOR INVESTMENT  5132.92  5120.87            NaN       NaN
# 2             SAVINGS - FCY    22.93    22.93      5/25/2022      0.00
# 3           SAVINGS - MINOR  1042.50  1039.98      1/11/2009      3.03
# 4           SAVINGS - MINOR  1005.43  1001.59     10/25/2023      4.61
#
#    TOTAL_DR  NO_CR  NO_DR  NET_FEE_INCOME  NET_INTEREST_INCOME CURRENCY_CD  \
# ...

# %%
merged_df.isna().sum()
# Out:
# PROD_ID                               0
# CIFNO                                 0
# ACCOUNT_NO                            0
# ACCOUNT_STATUS                    10400
# PRODUCT_DESC                          0
# SUB_PRODUCT_DESC                      0
# BAL_OS                                0
# AVG_BAL                               0
# LAST_TRAN_DATE                   182134
# TOTAL_CR                         377716
# TOTAL_DR                         383996
# NO_CR                            425299
# NO_DR                            431213
# NET_FEE_INCOME                        0
# NET_INTEREST_INCOME                   0
# CURRENCY_CD                           0
# BRANCH_CD                             0
# BRANCH_NAME                           0
# REGION_CD                             0
# REGION_NAME                           0
# YEARMON_x                             0
# SUB_PROD_ID                           0
# ACCOUNT_JOINT                   1525757
# ...

# %%
# Save the merged data as a new CSV file or update the existing CSV file
filepath=r"C:/Users/15694/Desktop/Cross selling/code/Michelle/final_data_with_Loan.csv"
merged_df.to_csv(filepath, index=False)

# %%
merged_df.shape
# Out:
# (1616891, 127)
